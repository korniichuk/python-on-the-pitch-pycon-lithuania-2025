# %%
import pandas as pd
import requests

# %%
API_TOKEN = "tqz8BHX2O0tyVADTRuvyBaGmLVrZkwcwrhfbRjR9T5ZAQWXovTUeBytl4onZ"
params = {"api_token": API_TOKEN, "include": "timeline"}

# %%
data = requests.get("https://api.sportmonks.com/v3/football/fixtures/19146817", params=params).json()["data"]
match = pd.json_normalize(data)

# %%
timeline = pd.json_normalize(match.timeline[0])
len(timeline)
# Out:
# 17

# %%
timeline.head(5)
# Out:
#           id  fixture_id  period_id  participant_id  type_id   section  \
# 0  148273597    19146817    5800865             246      126  timeline
# 1  148273435    19146817    5800865             246      126  timeline
# 2  148273535    19146817    5800865             246      126  timeline
# 3  148273629    19146817    5800865             273      126  timeline
# 4  148273735    19146817    5800865             273      126  timeline
#
#   player_id related_player_id player_name related_player_name  ...  info  \
# 0      None              None        None                None  ...  None
# 1      None              None        None                None  ...  None
# 2      None              None        None                None  ...  None
# 3      None              None        None                None  ...  None
# 4      None              None        None                None  ...  None
#
#      addition minute  extra_minute  injured on_bench  coach_id sub_type_id  \
# 0  3rd Corner     37           NaN     None    False      None        None
# 1  1st Corner      6           NaN     None    False      None        None
# 2  2nd Corner     24           NaN     None    False      None        None
# 3  6th Corner     38           NaN     None    False      None        None
# 4  8th Corner     45           NaN     None    False      None        None
#
#   detailed_period_id sort_order
# 0               None          3
# 1               None          1
# 2               None          2
# 3               None          6
# 4               None          8
#
# [5 rows x 21 columns]
