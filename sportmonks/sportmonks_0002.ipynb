# %%
import pandas as pd
import requests

# %%
API_TOKEN = "tqz8BHX2O0tyVADTRuvyBaGmLVrZkwcwrhfbRjR9T5ZAQWXovTUeBytl4onZ"
params = {"api_token": API_TOKEN}

# %% [markdown]
# #### Fixtures (matches) by date (`YYYY-MM-DD`)

# %%
date = "2025-04-21"
data= requests.get(f"https://api.sportmonks.com/v3/football/fixtures/date/{date}", params=params).json()["data"]
matches = pd.json_normalize(data)
matches
# Out:
#          id  sport_id  league_id  season_id  stage_id group_id aggregate_id  \
# 0  19404981         1        271      23584  77471147     None         None
# 1  19404982         1        271      23584  77471147     None         None
# 2  19404953         1        271      23584  77471146     None         None
# 3  19404954         1        271      23584  77471146     None         None
#
#    round_id  state_id  venue_id                            name  \
# 0    369912         5      4832  Vejle Boldklub vs Silkeborg IF
# 1    369912         5      1467    Viborg FF vs Lyngby Boldklub
# 2    369902         5      5659        Brøndby IF vs Randers FC
# 3    369902         5      5655             FC København vs AGF
#
#            starting_at                        result_info  leg details  \
# 0  2025-04-21 12:00:00  Silkeborg IF won after full-time.  1/1    None
# 1  2025-04-21 12:00:00                Game ended in draw.  1/1    None
# 2  2025-04-21 14:00:00    Brøndby IF won after full-time.  1/1    None
# 3  2025-04-21 16:00:00  FC København won after full-time.  1/1    None
#
#    length  placeholder  has_odds  has_premium_odds  starting_at_timestamp
# 0      90        False      True              True             1745236800
# 1      90        False      True              True             1745236800
# 2      90        False      True              True             1745244000
# 3      90        False      True              True             1745251200
